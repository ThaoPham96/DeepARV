# %% [markdown]
# <a href="https://colab.research.google.com/github/ThaoPham96/DeepARV/blob/main/DeepARV_Chemberta_construction_revised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**DeepARV: Ensemble Deep Learning to Predict Drug-Drug Interaction (DDI) of Clinical Relevance with Antiretrovial Therapy (ARV)**
#
# In this study, we built an esemble learning algorithm to predict DDIs of clinical relevance between ARVs and comedications.
#
# DDI severity grading between 29,142 drug pairs was extracted from the Liverpool HIV Drug Interaction database, https://www.hiv-druginteractions.org/. Molecular structure of each drug was converted to Morgan fingerprints where each atom was represented in a numerical format and compared by constructing drug similarity profiles. We developed DeepARV, a feed-forward neural network where drug similarity profiles were fed into the input layer and outputted 4 categories of DDI as 'traffic light' system:
#
# *   Red: drugs should not be co-administered
# *   Amber: interaction of potential clinical relevance manageable by monitoring/dose adjustment
# *   Yellow: interaction of weak relevance
# *   Green: no expected interaction
#
# The imbalance in the distribution of DDI severity grades was addressed by undersampling and applying ensemble learning during training of DeepARV.

# %% [markdown]
# # Imports and installations

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorboard
# !pip install tensorflow_addons

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import keras
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Activation, Dropout
from tensorflow.keras.callbacks import Callback
import tensorflow.experimental.numpy as tnp
import math
import timeit
import datetime, os
import pandas as pd
from numpy import argmax
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow_addons as tfa
from sklearn.utils import class_weight
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from tqdm import tqdm
from deep_arv_utils import *
from matplotlib.colors import LinearSegmentedColormap
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.15.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.5.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.23.5)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard) (3.2.2)
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)

# %%
def load_training_data():
  print('Loading data...')
  x_train = np.load('/content/drive/MyDrive/liverpool_hiv/chemberta/x_train.npy')
  y_train = np.load('/content/drive/MyDrive/liverpool_hiv/chemberta/y_train.npy')
  train_df = pd.DataFrame(data=x_train)
  train_df['label'] = y_train
  unique, counts = np.unique(y_train, return_counts=True)
  print('Distribution of DDI class in training set')
  print(pd.DataFrame((['Green', 'Yellow', 'Amber', 'Red'], unique, counts), index=['Clinical_label', 'Numeric_label', 'Amount']).T)
  print('\n########################################\n')
  print('Spliting data into 5 stratified folds...')
  train_5fold = stratified_fold_split(train_df,   class_num = 4, folds=5)
  return train_5fold

def load_independent_test_set():
  print('\nLoading independent test set')
  # Load preprocessed X
  independent_test = pd.DataFrame(np.load('/content/drive/MyDrive/liverpool_hiv/chemberta/x_test.npy'))
  # Load preprocessed Y
  independent_test['label'] = np.load('/content/drive/MyDrive/liverpool_hiv/chemberta/y_test.npy')
  print('\nDDI distribution in independent test set')
  print('-------------------------------------------')
  print(count_uniques_ddi(independent_test))
  return independent_test

# %% [markdown]
# # DeepARV Class

# %%
class DeepARV_ensemble:
  ''' Training of DeepARV '''
  def __init__(self, train_df=None, test_df=None, n_models=5):

    # Load data
    self.train_df = train_df
    self.test_ds = test_df
    self.n_models = n_models


  def build_model(self, feature):
    ''' Builds a single model '''
    model = Sequential()
    model.add(Dense(1024, activation='relu', input_shape=(feature,))),
    model.add(Dropout(0.2)),
    model.add(Dense(512, activation='relu')),
    model.add(Dropout(0.2)),
    model.add(Dense(256, activation='relu')),
    model.add(Dropout(0.2)),
    model.add(Dense(128, activation='relu')),
    model.add(Dropout(0.2)),
    model.add(Dense(4, activation='softmax'))
    tf.keras.optimizers.Adam(learning_rate=0.001,
                            beta_1=0.9, beta_2=0.999,
                            epsilon=1e-07,
                            amsgrad=False,
                            name='Adam')
    model.compile(optimizer='Adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    self.model = model
    return model

  #Undersample the majority
  def undersample(self ):
      minority = self.train_df[self.train_df.label != 0]
      majority = self.train_df[self.train_df.label == 0
                               ].sample(frac=1, random_state=42
                                        ).reset_index(drop=True)

      # Split majority class for undersampling
      majority_dict = split_majority(majority,5,2762)
      train_split_dict = {} #dict to hold final training df
      n_model = 5
      self.undersampled_feature_dict = {}
      self.undersampled_label_dict = {}
      print('\n########################################\n')
      print('---------------------------------------')
      print('DDI 4-fold training distribution BEFORE undersampling : ',
            count_uniques_ddi(self.train_df))
      print('---------------------------------------')

      for i in range(5):
          train_split_dict[i] = pd.concat([majority_dict[i],minority]
                                          ).sample(frac=1,random_state=42
                                          ).reset_index(drop=True)
          print('---------------------------------------')
          print('DDI distribution for training model '+str(i)+
                ' AFTER undersampling: \n',
                count_uniques_ddi(train_split_dict[i]))
          self.undersampled_feature_dict[i] = train_split_dict[i
                                                               ].drop(
                                                              columns='label')
          self.undersampled_label_dict[i] = train_split_dict[i].label.dropna()
      return

  def save_models(self,ensemble_id):
    path_to_save = '/content/drive/MyDrive/liverpool_hiv/chemberta/Untitled Folder/' + str(ensemble_id)
    os.makedirs(path_to_save, exist_ok=True)
    for i in range(self.n_models):
      print('Saving iteration...')
      self.model_dict[i].save(path_to_save + '/DeepARV_model'+ str(i)+'.keras')
    print('Cross Validation Models ',  str(ensemble_id) ,' saved.')

  def train(self, n_models=5):
        print('\n########################################\n')
        print('Building models, balancing with class weights and training ...\n')
        self.model_dict = {}
        for i in range(n_models):
            print('Training model: ', i)
            class_weights = class_weight.compute_class_weight(
                            class_weight='balanced',
                            classes = np.unique(self.undersampled_label_dict[i]),
                            y = self.undersampled_label_dict[i])
            class_weights_model = dict(zip(np.unique(
                                  self.undersampled_label_dict[i]),
                                           class_weights))
            self.model_dict[i] = self.build_model(1536)
            early_stopping = EarlyStopping(monitor='val_loss',
                                           patience=10,
                                           restore_best_weights=True)
            self.model_dict[i].fit(self.undersampled_feature_dict[i],
                                   self.undersampled_label_dict[i],
                                   epochs=30,
                                   validation_split=0.1,
                                   batch_size = 128,
                                   class_weight=class_weights_model,
                                   callbacks=[early_stopping])


  def test(self):
      # Predict from all models
      print('\nPredicting for test set for each model, aggregating for final vote...\n')
      all_results = {}
      for i in range(5):
          all_results[i] = self.model_dict[i].predict(self.test_ds.iloc[:,:-1])

      self.all_results_values = np.array(list(all_results.values()))
      self.soft_vote_mean = self.all_results_values.mean(axis=0)
      soft_vote = self.soft_vote_mean.argmax(axis=1)
      self.df_vote = pd.DataFrame(data=soft_vote, columns=['final_vote'])

      self.macro_results, self.each_class_results = calculate_macro_metrics(
                                                    self.df_vote , self.test_ds)


      self.all_results_df = pd.DataFrame(self.each_class_results,
                                          index=['Green','Yellow',
                                                'Amber','Red','Macro'],
                            columns =['Accuracy','Precision','Sensitivity',
                                'Specificity','F1_score', 'Balanced Accuracy'])

  def visualize_confusion_matrix(self):
    print('\n ------------------------------')
    print('Plotting confusion matrix ...')
    y_pred = self.df_vote.final_vote
    y_test = self.test_ds['label']
    plot_norm_confusion_matrix(y_pred, y_test)
    plot_confusion_matrix(y_pred, y_test)

  def load_pretrained_models(self, ens):
    self.model_dict = {}

    print('\nLoading pretrained models...\n')
    for i in tqdm(range(self.n_models)):
      self.model_dict[i] = tf.keras.models.load_model('/content/drive/MyDrive/liverpool_hiv/chemberta/Untitled Folder/'+ str(ens) + '/DeepARV_model'+str(i)+'.keras')
    print('\n')

# %% [markdown]
# #Train

# %%
def DeepARV_5_fold_cross_validation():

  # Load training data into dictionary with 5 folds
  train_5fold = load_training_data()

  #Store accuracy, precision,  sensitivity, specificity, f1_score, BAcc for each
  # class and macro.
  cv5_macro_results = np.zeros((5,6))
  cv5_each_class_results = []

  # Storage for each ensemble
  ensemble_dict = {}

  # iterate through each fold as test, remaining as training
  for f in range(5):
    print('\n########################################')
    print('\nRunning fold: ', f)
    folds = [i for i in range(5)]
    test_idx = folds.pop(f)
    test_ds = train_5fold[test_idx]
    train_ds = pd.concat([train_5fold[folds[0]], train_5fold[folds[1]],
                  train_5fold[folds[2]], train_5fold[folds[3]]])

    # Build ensemble, undersample to balance data, train and test.
    deepARV_ensemble = DeepARV_ensemble(train_ds, test_ds)
    deepARV_ensemble.undersample()
    deepARV_ensemble.train()
    deepARV_ensemble.test()
    deepARV_ensemble.save_models(f)
    ensemble_dict[f] = deepARV_ensemble.model_dict
    cv5_macro_results[f] = deepARV_ensemble.macro_results
    cv5_each_class_results.append(deepARV_ensemble.each_class_results)

  # Format and print macro results for each ensemble.
  result_df = print_final_result(cv5_each_class_results)


  return result_df, ensemble_dict



result_df, ensemble_dict =  DeepARV_5_fold_cross_validation()
print('\n ----  Results for each ensemble ---- \n ')
result_df
# Out:
# Loading data...
# Distribution of DDI class in training set
#   Clinical_label Numeric_label Amount
# 0          Green             0  17252
# 1         Yellow             1   1839
# 2          Amber             2   3794
# 3            Red             3   1119
#
# ########################################
#
# Spliting data into 5 stratified folds...
# --------------------------
#   Clinical_label Numeric_label Amount
# 0          Green             0   3451
# 1         Yellow             1    368
# 2          Amber             2    759
# 3            Red             3    224
# --------------------------
#   Clinical_label Numeric_label Amount
# 0          Green             0   3451
# 1         Yellow             1    368
# 2          Amber             2    759
# 3            Red             3    224
# --------------------------
#   Clinical_label Numeric_label Amount
# 0          Green             0   3450
# 1         Yellow             1    368
# 2          Amber             2    759
# 3            Red             3    224
# --------------------------
#   Clinical_label Numeric_label Amount
# 0          Green             0   3450
# 1         Yellow             1    368
# 2          Amber             2    759
# 3            Red             3    224
# --------------------------
#   Clinical_label Numeric_label Amount
# 0          Green             0   3450
# 1         Yellow             1    367
# 2          Amber             2    758
# 3            Red             3    223
#
# ########################################
#
# Running fold:  0
#
# ########################################
#
# ---------------------------------------
# DDI 4-fold training distribution BEFORE undersampling :    Clinical_label Numeric_label Amount
# 0          Green             0  13801
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
# ---------------------------------------
# ---------------------------------------
# DDI distribution for training model 0 AFTER undersampling:
#    Clinical_label Numeric_label Amount
# 0          Green             0   2762
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
# ---------------------------------------
# DDI distribution for training model 1 AFTER undersampling:
#    Clinical_label Numeric_label Amount
# 0          Green             0   2762
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
# ---------------------------------------
# DDI distribution for training model 2 AFTER undersampling:
#    Clinical_label Numeric_label Amount
# 0          Green             0   2762
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
# ---------------------------------------
# DDI distribution for training model 3 AFTER undersampling:
#    Clinical_label Numeric_label Amount
# 0          Green             0   2762
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
# ---------------------------------------
# DDI distribution for training model 4 AFTER undersampling:
#    Clinical_label Numeric_label Amount
# 0          Green             0   2753
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
#
# ########################################
#
# Building models, balancing with class weights and training ...
#
# Training model:  0
# Epoch 1/30
# 58/58 [==============================] - 3s 13ms/step - loss: 1.3879 - accuracy: 0.3376 - val_loss: 1.1997 - val_accuracy: 0.4370
# Epoch 2/30
# 58/58 [==============================] - 0s 7ms/step - loss: 1.2076 - accuracy: 0.4468 - val_loss: 1.2067 - val_accuracy: 0.3892
# Epoch 3/30
# 58/58 [==============================] - 0s 9ms/step - loss: 1.1280 - accuracy: 0.4797 - val_loss: 1.1026 - val_accuracy: 0.4749
# Epoch 4/30
# 58/58 [==============================] - 1s 9ms/step - loss: 1.0179 - accuracy: 0.5312 - val_loss: 0.9521 - val_accuracy: 0.5643
# Epoch 5/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.9496 - accuracy: 0.5700 - val_loss: 0.9870 - val_accuracy: 0.5398
# Epoch 6/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.8834 - accuracy: 0.5987 - val_loss: 1.1095 - val_accuracy: 0.5153
# Epoch 7/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.8282 - accuracy: 0.6184 - val_loss: 0.9060 - val_accuracy: 0.5863
# Epoch 8/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.7975 - accuracy: 0.6359 - val_loss: 0.8990 - val_accuracy: 0.6206
# Epoch 9/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.7595 - accuracy: 0.6526 - val_loss: 0.8947 - val_accuracy: 0.6181
# Epoch 10/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7169 - accuracy: 0.6631 - val_loss: 0.8075 - val_accuracy: 0.6426
# Epoch 11/30
# 58/58 [==============================] - 0s 5ms/step - loss: 0.6958 - accuracy: 0.6806 - val_loss: 0.7799 - val_accuracy: 0.6610
# Epoch 12/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6618 - accuracy: 0.6928 - val_loss: 0.7844 - val_accuracy: 0.6695
# Epoch 13/30
# 58/58 [==============================] - 0s 5ms/step - loss: 0.6537 - accuracy: 0.6981 - val_loss: 0.8132 - val_accuracy: 0.6585
# Epoch 14/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6160 - accuracy: 0.7201 - val_loss: 0.7827 - val_accuracy: 0.6683
# Epoch 15/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5858 - accuracy: 0.7261 - val_loss: 0.7494 - val_accuracy: 0.6965
# Epoch 16/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5898 - accuracy: 0.7249 - val_loss: 0.7402 - val_accuracy: 0.6769
# Epoch 17/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5510 - accuracy: 0.7427 - val_loss: 0.7618 - val_accuracy: 0.6732
# Epoch 18/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5573 - accuracy: 0.7434 - val_loss: 0.7428 - val_accuracy: 0.6940
# Epoch 19/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.5442 - accuracy: 0.7495 - val_loss: 0.7053 - val_accuracy: 0.6965
# Epoch 20/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.5299 - accuracy: 0.7499 - val_loss: 0.6999 - val_accuracy: 0.6952
# Epoch 21/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5048 - accuracy: 0.7555 - val_loss: 0.7305 - val_accuracy: 0.6867
# Epoch 22/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4990 - accuracy: 0.7648 - val_loss: 0.7247 - val_accuracy: 0.7160
# Epoch 23/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4852 - accuracy: 0.7723 - val_loss: 0.6859 - val_accuracy: 0.7062
# Epoch 24/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4847 - accuracy: 0.7687 - val_loss: 0.6704 - val_accuracy: 0.7271
# Epoch 25/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4609 - accuracy: 0.7821 - val_loss: 0.6863 - val_accuracy: 0.7136
# Epoch 26/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.
# Epoch 1/30
# 58/58 [==============================] - 2s 9ms/step - loss: 1.3992 - accuracy: 0.3336 - val_loss: 1.2288 - val_accuracy: 0.4044
# Epoch 2/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2232 - accuracy: 0.4237 - val_loss: 1.1784 - val_accuracy: 0.4314
# Epoch 3/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1166 - accuracy: 0.4762 - val_loss: 1.0510 - val_accuracy: 0.5184
# Epoch 4/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0083 - accuracy: 0.5288 - val_loss: 1.0095 - val_accuracy: 0.5711
# Epoch 5/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9523 - accuracy: 0.5516 - val_loss: 0.9710 - val_accuracy: 0.5625
# Epoch 6/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8917 - accuracy: 0.5867 - val_loss: 0.8684 - val_accuracy: 0.6434
# Epoch 7/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8341 - accuracy: 0.6138 - val_loss: 0.8586 - val_accuracy: 0.6422
# Epoch 8/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7846 - accuracy: 0.6351 - val_loss: 0.8592 - val_accuracy: 0.6373
# Epoch 9/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7674 - accuracy: 0.6400 - val_loss: 0.8879 - val_accuracy: 0.6422
# Epoch 10/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7197 - accuracy: 0.6599 - val_loss: 0.8526 - val_accuracy: 0.6409
# Epoch 11/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6988 - accuracy: 0.6744 - val_loss: 0.8655 - val_accuracy: 0.6385
# Epoch 12/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6454 - accuracy: 0.6962 - val_loss: 0.8109 - val_accuracy: 0.6740
# Epoch 13/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6433 - accuracy: 0.6992 - val_loss: 0.7638 - val_accuracy: 0.6850
# Epoch 14/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6029 - accuracy: 0.7135 - val_loss: 0.7579 - val_accuracy: 0.6973
# Epoch 15/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6034 - accuracy: 0.7104 - val_loss: 0.8702 - val_accuracy: 0.6299
# Epoch 16/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6121 - accuracy: 0.7093 - val_loss: 0.7735 - val_accuracy: 0.6814
# Epoch 17/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5598 - accuracy: 0.7337 - val_loss: 0.8144 - val_accuracy: 0.6703
# Epoch 18/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5476 - accuracy: 0.7411 - val_loss: 0.8213 - val_accuracy: 0.6667
# Epoch 19/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5349 - accuracy: 0.7415 - val_loss: 0.7450 - val_accuracy: 0.6985
# Epoch 20/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5233 - accuracy: 0.7512 - val_loss: 0.7823 - val_accuracy: 0.6961
# Epoch 21/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5110 - accuracy: 0.7622 - val_loss: 0.7536 - val_accuracy: 0.7194
# Epoch 22/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4805 - accuracy: 0.7711 - val_loss: 0.7555 - val_accuracy: 0.7206
# Epoch 23/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4846 - accuracy: 0.7694 - val_loss: 0.7455 - val_accuracy: 0.7108
# Epoch 24/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4831 - accuracy: 0.7751 - val_loss: 0.7373 - val_accuracy: 0.7181
# Epoch 25/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4556 - accuracy: 0.7781 - val_loss: 0.7265 - val_accuracy: 0.7169
# Epoch 26/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4590 - accuracy: 0.7813 - val_loss: 0.7198 - val_accuracy: 0.7316
# Epoch 27/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.4426 - accuracy: 0.7901 - val_loss: 0.7306 - val_accuracy: 0.7194
# Epoch 28/30
# 58/58 [==============================] - 0s 9ms/step - loss: 0.4288 - accuracy: 0.7954 - val_loss: 0.7371 - val_accuracy: 0.7181
# Epoch 29/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.4374 - accuracy: 0.7987 - val_loss: 0.7717 - val_accuracy: 0.7255
# Epoch 30/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.4179 - accuracy: 0.7974 - val_loss: 0.7387 - val_accuracy: 0.7414
#
# Predicting for test set for each model, aggregating for final vote...
#
# 151/151 [==============================] - 1s 3ms/step
# 151/151 [==============================] - 1s 3ms/step
# 151/151 [==============================] - 1s 3ms/step
# 151/151 [==============================] - 0s 2ms/step
# 151/151 [==============================] - 0s 2ms/step
# Saving iteration...
# Saving iteration...
# Saving iteration...
# Saving iteration...
# Saving iteration...
# Cross Validation Models  0  saved.
#
# ########################################
#
# Running fold:  1
#
# ########################################
#
# ---------------------------------------
# DDI 4-fold training distribution BEFORE undersampling :    Clinical_label Numeric_label Amount
# 0          Green             0  13801
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
# ---------------------------------------
# ---------------------------------------
# DDI distribution for training model 0 AFTER undersampling:
#    Clinical_label Numeric_label Amount
# 0          Green             0   2762
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
# ---------------------------------------
# DDI distribution for training model 1 AFTER undersampling:
#    Clinical_label Numeric_label Amount
# 0          Green             0   2762
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
# ---------------------------------------
# DDI distribution for training model 2 AFTER undersampling:
#    Clinical_label Numeric_label Amount
# 0          Green             0   2762
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
# ---------------------------------------
# DDI distribution for training model 3 AFTER undersampling:
#    Clinical_label Numeric_label Amount
# 0          Green             0   2762
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
# ---------------------------------------
# DDI distribution for training model 4 AFTER undersampling:
#    Clinical_label Numeric_label Amount
# 0          Green             0   2753
# 1         Yellow             1   1471
# 2          Amber             2   3035
# 3            Red             3    895
#
# ########################################
#
# Building models, balancing with class weights and training ...
#
# Training model:  0
# Epoch 1/30
# 58/58 [==============================] - 2s 9ms/step - loss: 1.3966 - accuracy: 0.3229 - val_loss: 1.2557 - val_accuracy: 0.3819
# Epoch 2/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2309 - accuracy: 0.4195 - val_loss: 1.2328 - val_accuracy: 0.4137
# Epoch 3/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1400 - accuracy: 0.4763 - val_loss: 1.0775 - val_accuracy: 0.4639
# Epoch 4/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0454 - accuracy: 0.5184 - val_loss: 1.0296 - val_accuracy: 0.5116
# Epoch 5/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9699 - accuracy: 0.5534 - val_loss: 1.1631 - val_accuracy: 0.4590
# Epoch 6/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9153 - accuracy: 0.5813 - val_loss: 1.0047 - val_accuracy: 0.5435
# Epoch 7/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8474 - accuracy: 0.6153 - val_loss: 0.9087 - val_accuracy: 0.6047
# Epoch 8/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8103 - accuracy: 0.6297 - val_loss: 0.8751 - val_accuracy: 0.6157
# Epoch 9/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7766 - accuracy: 0.6511 - val_loss: 0.8242 - val_accuracy: 0.6353
# Epoch 10/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.7558 - accuracy: 0.6510 - val_loss: 0.8052 - val_accuracy: 0.6450
# Epoch 11/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.6968 - accuracy: 0.6836 - val_loss: 0.8287 - val_accuracy: 0.6426
# Epoch 12/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.6752 - accuracy: 0.6853 - val_loss: 0.7400 - val_accuracy: 0.6854
# Epoch 13/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.6429 - accuracy: 0.7043 - val_loss: 0.7684 - val_accuracy: 0.6781
# Epoch 14/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.6290 - accuracy: 0.7039 - val_loss: 0.7537 - val_accuracy: 0.6793
# Epoch 15/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.6023 - accuracy: 0.7208 - val_loss: 0.7811 - val_accuracy: 0.6805
# Epoch 16/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5968 - accuracy: 0.7249 - val_loss: 0.7305 - val_accuracy: 0.7050
# Epoch 17/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5618 - accuracy: 0.7378 - val_loss: 0.7150 - val_accuracy: 0.7038
# Epoch 18/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5431 - accuracy: 0.7484 - val_loss: 0.7214 - val_accuracy: 0.7050
# Epoch 19/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5446 - accuracy: 0.7388 - val_loss: 0.7458 - val_accuracy: 0.6903
# Epoch 20/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5302 - accuracy: 0.7469 - val_loss: 0.6918 - val_accuracy: 0.7148
# Epoch 21/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5147 - accuracy: 0.7645 - val_loss: 0.6837 - val_accuracy: 0.7393
# Epoch 22/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.4909 - accuracy: 0.7709 - val_loss: 0.7059 - val_accuracy: 0.7111
# Epoch 23/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4857 - accuracy: 0.7713 - val_loss: 0.7081 - val_accuracy: 0.7234
# Epoch 24/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4840 - accuracy: 0.7747 - val_loss: 0.7168 - val_accuracy: 0.7001
# Epoch 25/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4788 - accuracy: 0.7803 - val_loss: 0.6851 - val_accuracy: 0.7344
# Epoch 26/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.
30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.4463 - accuracy: 0.7838 - val_loss: 0.7010 - val_accuracy: 0.7087
# Epoch 29/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4472 - accuracy: 0.7900 - val_loss: 0.7034 - val_accuracy: 0.7062
# Epoch 30/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4401 - accuracy: 0.7909 - val_loss: 0.6597 - val_accuracy: 0.7405
# Training model:  2
# Epoch 1/30
# 58/58 [==============================] - 2s 9ms/step - loss: 1.4036 - accuracy: 0.3290 - val_loss: 1.4081 - val_accuracy: 0.2852
# Epoch 2/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2346 - accuracy: 0.4206 - val_loss: 1.1297 - val_accuracy: 0.4908
# Epoch 3/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1348 - accuracy: 0.4794 - val_loss: 1.0784 - val_accuracy: 0.4994
# Epoch 4/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0642 - accuracy: 0.5133 - val_loss: 1.0645 - val_accuracy: 0.5006
# Epoch 5/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9662 - accuracy: 0.5564 - val_loss: 1.0452 - val_accuracy: 0.5177
# Epoch 6/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9083 - accuracy: 0.5762 - val_loss: 0.9077 - val_accuracy: 0.5973
# Epoch 7/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8455 - accuracy: 0.6051 - val_loss: 0.8530 - val_accuracy: 0.6255
# Epoch 8/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7919 - accuracy: 0.6417 - val_loss: 0.8409 - val_accuracy: 0.6365
# Epoch 9/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7586 - accuracy: 0.6484 - val_loss: 0.9095 - val_accuracy: 0.6022
# Epoch 10/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7541 - accuracy: 0.6516 - val_loss: 0.8363 - val_accuracy: 0.6426
# Epoch 11/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6866 - accuracy: 0.6838 - val_loss: 0.8665 - val_accuracy: 0.6401
# Epoch 12/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6630 - accuracy: 0.6874 - val_loss: 0.8671 - val_accuracy: 0.6328
# Epoch 13/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6524 - accuracy: 0.6990 - val_loss: 0.7606 - val_accuracy: 0.6903
# Epoch 14/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6558 - accuracy: 0.6944 - val_loss: 0.7814 - val_accuracy: 0.6610
# Epoch 15/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6203 - accuracy: 0.7152 - val_loss: 0.7062 - val_accuracy: 0.6940
# Epoch 16/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5881 - accuracy: 0.7233 - val_loss: 0.6993 - val_accuracy: 0.7111
# Epoch 17/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5765 - accuracy: 0.7302 - val_loss: 0.7460 - val_accuracy: 0.6793
# Epoch 18/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5793 - accuracy: 0.7260 - val_loss: 0.7013 - val_accuracy: 0.6989
# Epoch 19/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5556 - accuracy: 0.7465 - val_loss: 0.6933 - val_accuracy: 0.6952
# Epoch 20/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5225 - accuracy: 0.7531 - val_loss: 0.6933 - val_accuracy: 0.6940
# Epoch 21/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5234 - accuracy: 0.7582 - val_loss: 0.6625 - val_accuracy: 0.7197
# Epoch 22/30
# 58/58 [==============================] - 0s 9ms/step - loss: 0.4781 - accuracy: 0.7727 - val_loss: 0.6874 - val_accuracy: 0.7136
# Epoch 23/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4827 - accuracy: 0.7766 - val_loss: 0.6557 - val_accuracy: 0.7393
# Epoch 24/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4730 - accuracy: 0.7762 - val_loss: 0.6526 - val_accuracy: 0.7246
# Epoch 25/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.4607 - accuracy: 0.7791 - val_loss: 0.6886 - val_accuracy: 0.7209
# Epoch 26/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4545 - accuracy: 0.7876 - val_loss: 0.6371 - val_accuracy: 0.7368
# Epoch 27/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.4458 - accuracy: 0.7895 - val_loss: 0.6342 - val_accuracy: 0.7417
# Epoch 28/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4226 - accuracy: 0.8019 - val_loss: 0.7161 - val_accuracy: 0.7295
# Epoch 29/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4462 - accuracy: 0.7898 - val_loss: 0.6561 - val_accuracy: 0.7430
# Epoch 30/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.4042 - accuracy: 0.8106 - val_loss: 0.6350 - val_accuracy: 0.7528
# Training model:  3
# Epoch 1/30
# 58/58 [==============================] - 2s 9ms/step - loss: 1.4035 - accuracy: 0.3221 - val_loss: 1.3309 - val_accuracy: 0.2974
# Epoch 2/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2347 - accuracy: 0.4168 - val_loss: 1.1532 - val_accuracy: 0.4333
# Epoch 3/30
# 58/58 [==============================] - 0s 7ms/step - loss: 1.1493 - accuracy: 0.4617 - val_loss: 1.1066 - val_accuracy: 0.4602
# Epoch 4/30
# 58/58 [==============================] - 1s 9ms/step - loss: 1.0453 - accuracy: 0.5076 - val_loss: 0.9335 - val_accuracy: 0.6108
# Epoch 5/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.9858 - accuracy: 0.5404 - val_loss: 0.9320 - val_accuracy: 0.5802
# Epoch 6/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.9055 - accuracy: 0.5745 - val_loss: 0.9428 - val_accuracy: 0.5716
# Epoch 7/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.8482 - accuracy: 0.6133 - val_loss: 0.8832 - val_accuracy: 0.6059
# Epoch 8/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.8286 - accuracy: 0.6213 - val_loss: 0.8253 - val_accuracy: 0.6389
# Epoch 9/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.7745 - accuracy: 0.6431 - val_loss: 0.8262 - val_accuracy: 0.6414
# Epoch 10/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.7295 - accuracy: 0.6594 - val_loss: 0.8007 - val_accuracy: 0.6426
# Epoch 11/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.6980 - accuracy: 0.6670 - val_loss: 0.8623 - val_accuracy: 0.6206
# Epoch 12/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.6579 - accuracy: 0.6926 - val_loss: 0.8066 - val_accuracy: 0.6475
# Epoch 13/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.6683 - accuracy: 0.6862 - val_loss: 0.7480 - val_accuracy: 0.6903
# Epoch 14/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.6300 - accuracy: 0.7062 - val_loss: 0.7540 - val_accuracy: 0.6744
# Epoch 15/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.6150 - accuracy: 0.7190 - val_loss: 0.7872 - val_accuracy: 0.6683
# Epoch 16/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5928 - accuracy: 0.7137 - val_loss: 0.7418 - val_accuracy: 0.6928
# Epoch 17/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5614 - accuracy: 0.7284 - val_loss: 0.6754 - val_accuracy: 0.7197
# Epoch 18/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5383 - accuracy: 0.7480 - val_loss: 0.7322 - val_accuracy: 0.6879
# Epoch 19/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5320 - accuracy: 0.7405 - val_loss: 0.6570 - val_accuracy: 0.7271
# Epoch 20/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5403 - accuracy: 0.7516 - val_loss: 0.7036 - val_accuracy: 0.6842
# Epoch 21/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5174 - accuracy: 0.7539 - val_loss: 0.6518 - val_accuracy: 0.7332
# Epoch 22/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4970 - accuracy: 0.7642 - val_loss: 0.6112 - val_accuracy: 0.7515
# Epoch 23/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4936 - accuracy: 0.7625 - val_loss: 0.6595 - val_accuracy: 0.7222
# Epoch 24/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.4878 - accuracy: 0.7650 - val_loss: 0.6196 - val_accuracy: 0.7332
# Epoch 25/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4650 - accuracy: 0.7814 - val_loss: 0.6356 - val_accuracy: 0.7515
# Epoch 26/30
# 58/58 [==============================] - 0s 5ms/step - loss: 0.4642 - accuracy: 0.7747 - val_loss: 0.6247 - val_accuracy: 0.7576
# Epoch 27/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4570 - accuracy: 0.7859 - val_loss: 0.6404 - val_accuracy: 0.7283
# Epoch 28/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4373 - accuracy: 0.7872 - val_loss: 0.6618 - val_accuracy: 0.7258
# Epoch 29/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4526 - accuracy: 0.7860 - val_loss: 0.6285 - val_accuracy: 0.7381
# Epoch 30/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4232 - accuracy: 0.7951 - val_loss: 0.6313 - val_accuracy: 0.7564
# Training model:  4
# Epoch 1/30
# 58/58 [==============================] - 2s 10ms/step - loss: 1.4025 - accuracy: 0.3374 - val_loss: 1.2186 - val_accuracy: 0.4387
# Epoch 2/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2130 - accuracy: 0.4282 - val_loss: 1.1276 - val_accuracy: 0.4779
# Epoch 3/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1195 - accuracy: 0.4786 - val_loss: 1.1897 - val_accuracy: 0.4596
# Epoch 4/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0186 - accuracy: 0.5294 - val_loss: 1.1065 - val_accuracy: 0.5074
# Epoch 5/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9643 - accuracy: 0.5489 - val_loss: 0.9559 - val_accuracy: 0.5931
# Epoch 6/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8882 - accuracy: 0.5864 - val_loss: 1.1339 - val_accuracy: 0.4975
# Epoch 7/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8480 - accuracy: 0.6068 - val_loss: 0.9725 - val_accuracy: 0.5968
# Epoch 8/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.7908 - accuracy: 0.6301 - val_loss: 0.8036 - val_accuracy: 0.6642
# Epoch 9/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.7471 - accuracy: 0.6540 - val_loss: 0.8774 - val_accuracy: 0.6275
# Epoch 10/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.7147 - accuracy: 0.6762 - val_loss: 0.8471 - val_accuracy: 0.6703
# Epoch 11/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.6844 - accuracy: 0.6825 - val_loss: 0.7526 - val_accuracy: 0.6912
# Epoch 12/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.6592 - accuracy: 0.6907 - val_loss: 0.7443 - val_accuracy: 0.6887
# Epoch 13/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.6471 - accuracy: 0.6987 - val_loss: 0.7275 - val_accuracy: 0.7034
# Epoch 14/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.6199 - accuracy: 0.7093 - val_loss: 0.7721 - val_accuracy: 0.6826
# Epoch 15/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.5962 - accuracy: 0.7281 - val_loss: 0.7481 - val_accuracy: 0.6936
# Epoch 16/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.5712 - accuracy: 0.7292 - val_loss: 0.7585 - val_accuracy: 0.6936
# Epoch 17/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.5698 - accuracy: 0.7250 - val_loss: 0.7238 - val_accuracy: 0.7096
# Epoch 18/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.5356 - accuracy: 0.7441 - val_loss: 0.7012 - val_accuracy: 0.7157
# Epoch 19/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.5348 - accuracy: 0.7469 - val_loss: 0.7020 - val_accuracy: 0.7157
# Epoch 20/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.4819 - accuracy: 0.7720 - val_loss: 0.7167 - val_accuracy: 0.7304
# Epoch 21/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5219 - accuracy: 0.7604 - val_loss: 0.6661 - val_accuracy: 0.7341
# Epoch 22/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4903 - accuracy: 0.7640 - val_loss: 0.7240 - val_accuracy: 0.7157
# Epoch 23/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4981 - accuracy: 0.7685 - val_loss: 0.6999 - val_accuracy: 0.7206
# Epoch 24/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4791 - accuracy: 0.7768 - val_loss: 0.7290 - val_accuracy: 0.7047
# Epoch 25/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4551 - accuracy: 0.7871 - val_loss: 0.6953 - val_accuracy: 0.7304
# Epoch 26/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4440 - accuracy: 0.7979 - val_loss: 0.6917 - val_accuracy: 0.7561
# Epoch 27/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4308 - accuracy: 0.8036 - val_loss: 0.6689 - val_accuracy: 0.7267
# Epoch 28/30
# ...
# Epoch 28/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4281 - accuracy: 0.7971 - val_loss: 0.7855 - val_accuracy: 0.7160
# Epoch 29/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4294 - accuracy: 0.7953 - val_loss: 0.7431 - val_accuracy: 0.7050
# Epoch 30/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4088 - accuracy: 0.8114 - val_loss: 0.7750 - val_accuracy: 0.7124
# Training model:  2
# Epoch 1/30
# 58/58 [==============================] - 3s 10ms/step - loss: 1.3916 - accuracy: 0.3288 - val_loss: 1.2607 - val_accuracy: 0.3905
# Epoch 2/30
# 58/58 [==============================] - 0s 7ms/step - loss: 1.2072 - accuracy: 0.4367 - val_loss: 1.1905 - val_accuracy: 0.4113
# Epoch 3/30
# 58/58 [==============================] - 0s 7ms/step - loss: 1.1237 - accuracy: 0.4688 - val_loss: 1.1482 - val_accuracy: 0.4431
# Epoch 4/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0313 - accuracy: 0.5202 - val_loss: 1.0560 - val_accuracy: 0.5092
# Epoch 5/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.9448 - accuracy: 0.5623 - val_loss: 0.9394 - val_accuracy: 0.5949
# Epoch 6/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.8925 - accuracy: 0.5929 - val_loss: 0.9343 - val_accuracy: 0.5826
# Epoch 7/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8376 - accuracy: 0.6146 - val_loss: 0.9998 - val_accuracy: 0.5532
# Epoch 8/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.7903 - accuracy: 0.6408 - val_loss: 0.9354 - val_accuracy: 0.6083
# Epoch 9/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7538 - accuracy: 0.6523 - val_loss: 0.9261 - val_accuracy: 0.5851
# Epoch 10/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.7239 - accuracy: 0.6673 - val_loss: 0.8801 - val_accuracy: 0.6328
# Epoch 11/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.6957 - accuracy: 0.6800 - val_loss: 0.8900 - val_accuracy: 0.6120
# Epoch 12/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.6681 - accuracy: 0.6883 - val_loss: 0.8762 - val_accuracy: 0.6353
# Epoch 13/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.6491 - accuracy: 0.7006 - val_loss: 0.8632 - val_accuracy: 0.6463
# Epoch 14/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.6270 - accuracy: 0.7058 - val_loss: 0.7915 - val_accuracy: 0.6720
# Epoch 15/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6211 - accuracy: 0.7111 - val_loss: 0.8576 - val_accuracy: 0.6450
# Epoch 16/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.6154 - accuracy: 0.7183 - val_loss: 0.8109 - val_accuracy: 0.6450
# Epoch 17/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.5815 - accuracy: 0.7287 - val_loss: 0.8462 - val_accuracy: 0.6365
# Epoch 18/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5544 - accuracy: 0.7396 - val_loss: 0.8108 - val_accuracy: 0.6499
# Epoch 19/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.5593 - accuracy: 0.7409 - val_loss: 0.7852 - val_accuracy: 0.6646
# Epoch 20/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5315 - accuracy: 0.7541 - val_loss: 0.7862 - val_accuracy: 0.6830
# Epoch 21/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.5267 - accuracy: 0.7513 - val_loss: 0.7938 - val_accuracy: 0.6781
# Epoch 22/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.5151 - accuracy: 0.7585 - val_loss: 0.7586 - val_accuracy: 0.6891
# Epoch 23/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.4932 - accuracy: 0.7695 - val_loss: 0.8106 - val_accuracy: 0.6634
# Epoch 24/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.4875 - accuracy: 0.7694 - val_loss: 0.8165 - val_accuracy: 0.6854
# Epoch 25/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.4705 - accuracy: 0.7770 - val_loss: 0.7309 - val_accuracy: 0.7062
# Epoch 26/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.4537 - accuracy: 0.7868 - val_loss: 0.7691 - val_accuracy: 0.6989
# Epoch 27/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.4474 - accuracy: 0.7830 - val_loss: 0.7279 - val_accuracy: 0.7124
# Epoch 28/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.4512 - accuracy: 0.7870 - val_loss: 0.7888 - val_accuracy: 0.6965
# Epoch 29/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4340 - accuracy: 0.7974 - val_loss: 0.7676 - val_accuracy: 0.6989
# Epoch 30/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.4310 - accuracy: 0.7970 - val_loss: 0.7277 - val_accuracy: 0.7173
# Training model:  3
# Epoch 1/30
# 58/58 [==============================] - 2s 9ms/step - loss: 1.3890 - accuracy: 0.3279 - val_loss: 1.2253 - val_accuracy: 0.4651
# Epoch 2/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2185 - accuracy: 0.4194 - val_loss: 1.1756 - val_accuracy: 0.4553
# Epoch 3/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.1150 - accuracy: 0.4795 - val_loss: 1.1328 - val_accuracy: 0.4749
# Epoch 4/30
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0148 - accuracy: 0.5376 - val_loss: 1.1105 - val_accuracy: 0.5006
# Epoch 5/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9415 - accuracy: 0.5586 - val_loss: 0.9737 - val_accuracy: 0.5765
# Epoch 6/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8795 - accuracy: 0.5897 - val_loss: 0.9387 - val_accuracy: 0.5936
# Epoch 7/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8533 - accuracy: 0.6010 - val_loss: 0.9595 - val_accuracy: 0.5973
# Epoch 8/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8043 - accuracy: 0.6300 - val_loss: 0.9608 - val_accuracy: 0.5924
# Epoch 9/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.7502 - accuracy: 0.6500 - val_loss: 0.9281 - val_accuracy: 0.6047
# Epoch 10/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.7220 - accuracy: 0.6666 - val_loss: 0.8944 - val_accuracy: 0.6071
# Epoch 11/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.6950 - accuracy: 0.6806 - val_loss: 0.9086 - val_accuracy: 0.6316
# Epoch 12/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.6662 - accuracy: 0.6899 - val_loss: 0.8177 - val_accuracy: 0.6561
# Epoch 13/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.6378 - accuracy: 0.7032 - val_loss: 0.8023 - val_accuracy: 0.6548
# Epoch 14/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.6173 - accuracy: 0.7103 - val_loss: 0.8199 - val_accuracy: 0.6499
# Epoch 15/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.6123 - accuracy: 0.7162 - val_loss: 0.8136 - val_accuracy: 0.6610
# Epoch 16/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.6060 - accuracy: 0.7138 - val_loss: 0.8055 - val_accuracy: 0.6781
# Epoch 17/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5799 - accuracy: 0.7272 - val_loss: 0.7721 - val_accuracy: 0.6842
# Epoch 18/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5491 - accuracy: 0.7377 - val_loss: 0.7183 - val_accuracy: 0.7148
# Epoch 19/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.5211 - accuracy: 0.7590 - val_loss: 0.7888 - val_accuracy: 0.6707
# Epoch 20/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.5332 - accuracy: 0.7509 - val_loss: 0.7701 - val_accuracy: 0.7001
# Epoch 21/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.5013 - accuracy: 0.7638 - val_loss: 0.7719 - val_accuracy: 0.7062
# Epoch 22/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4907 - accuracy: 0.7706 - val_loss: 0.7998 - val_accuracy: 0.7062
# Epoch 23/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.4729 - accuracy: 0.7796 - val_loss: 0.7804 - val_accuracy: 0.6940
# Epoch 24/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4849 - accuracy: 0.7713 - val_loss: 0.7877 - val_accuracy: 0.7038
# Epoch 25/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4553 - accuracy: 0.7851 - val_loss: 0.7840 - val_accuracy: 0.7013
# Epoch 26/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4393 - accuracy: 0.7921 - val_loss: 0.7950 - val_accuracy: 0.7111
# Epoch 27/30
# 58/58 [==============================] - 0s 8ms/step - loss: 0.4445 - accuracy: 0.7922 - val_loss: 0.8200 - val_accuracy: 0.6854
# Epoch 28/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4270 - accuracy: 0.8005 - val_loss: 0.7698 - val_accuracy: 0.7258
# Training model:  4
# Epoch 1/30
# 58/58 [==============================] - 2s 9ms/step - loss: 1.4056 - accuracy: 0.3314 - val_loss: 1.2309 - val_accuracy: 0.4767
# Epoch 2/30
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2307 - accuracy: 0.4262 - val_loss: 1.1279 - val_accuracy: 0.4547
# Epoch 3/30
# 58/58 [==============================] - 0s 7ms/step - loss: 1.1348 - accuracy: 0.4680 - val_loss: 1.1380 - val_accuracy: 0.4669
# Epoch 4/30
# 58/58 [==============================] - 0s 7ms/step - loss: 1.0580 - accuracy: 0.5020 - val_loss: 1.0206 - val_accuracy: 0.5417
# Epoch 5/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.9779 - accuracy: 0.5439 - val_loss: 0.9394 - val_accuracy: 0.5821
# Epoch 6/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8934 - accuracy: 0.5877 - val_loss: 1.0728 - val_accuracy: 0.5184
# Epoch 7/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.8613 - accuracy: 0.5977 - val_loss: 0.8533 - val_accuracy: 0.6262
# Epoch 8/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.8067 - accuracy: 0.6267 - val_loss: 0.7624 - val_accuracy: 0.6789
# Epoch 9/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7506 - accuracy: 0.6530 - val_loss: 0.8325 - val_accuracy: 0.6618
# Epoch 10/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7199 - accuracy: 0.6645 - val_loss: 0.7560 - val_accuracy: 0.6875
# Epoch 11/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.7003 - accuracy: 0.6777 - val_loss: 0.7676 - val_accuracy: 0.6838
# Epoch 12/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6850 - accuracy: 0.6855 - val_loss: 0.7964 - val_accuracy: 0.6581
# Epoch 13/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6590 - accuracy: 0.6855 - val_loss: 0.7208 - val_accuracy: 0.7034
# Epoch 14/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6242 - accuracy: 0.7092 - val_loss: 0.7541 - val_accuracy: 0.6949
# Epoch 15/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.6093 - accuracy: 0.7142 - val_loss: 0.7131 - val_accuracy: 0.7169
# Epoch 16/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5807 - accuracy: 0.7321 - val_loss: 0.7027 - val_accuracy: 0.7194
# Epoch 17/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.5743 - accuracy: 0.7307 - val_loss: 0.6731 - val_accuracy: 0.7304
# Epoch 18/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.5516 - accuracy: 0.7375 - val_loss: 0.6821 - val_accuracy: 0.7255
# Epoch 19/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.5395 - accuracy: 0.7498 - val_loss: 0.6480 - val_accuracy: 0.7353
# Epoch 20/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5267 - accuracy: 0.7518 - val_loss: 0.6771 - val_accuracy: 0.7304
# Epoch 21/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.5170 - accuracy: 0.7596 - val_loss: 0.6766 - val_accuracy: 0.7292
# Epoch 22/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.5103 - accuracy: 0.7612 - val_loss: 0.6342 - val_accuracy: 0.7708
# Epoch 23/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4785 - accuracy: 0.7769 - val_loss: 0.6759 - val_accuracy: 0.7488
# Epoch 24/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4635 - accuracy: 0.7817 - val_loss: 0.6686 - val_accuracy: 0.7488
# Epoch 25/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4933 - accuracy: 0.7672 - val_loss: 0.6391 - val_accuracy: 0.7525
# Epoch 26/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.4737 - accuracy: 0.7773 - val_loss: 0.6302 - val_accuracy: 0.7537
# Epoch 27/30
# 58/58 [==============================] - 1s 9ms/step - loss: 0.4397 - accuracy: 0.7941 - val_loss: 0.6570 - val_accuracy: 0.7574
# Epoch 28/30
# 58/58 [==============================] - 0s 9ms/step - loss: 0.4550 - accuracy: 0.7855 - val_loss: 0.6559 - val_accuracy: 0.7512
# Epoch 29/30
# 58/58 [==============================] - 0s 6ms/step - loss: 0.4297 - accuracy: 0.8026 - val_loss: 0.6388 - val_accuracy: 0.7623
# Epoch 30/30
# 58/58 [==============================] - 0s 7ms/step - loss: 0.4452 - accuracy: 0.7916 - val_loss: 0.6934 - val_accuracy: 0.7328
#
# Predicting for test set for each model, aggregating for final vote...
#
# 150/150 [==============================] - 0s 2ms/step
# 150/150 [==============================] - 0s 2ms/step
# 150/150 [==============================] - 0s 2ms/step
# 150/150 [==============================] - 0s 2ms/step
# 150/150 [==============================] - 0s 2ms/step
# Saving iteration...
# Saving iteration...
# Saving iteration...
# Saving iteration...
# Saving iteration...
# Cross Validation Models  4  saved.
#
#  ----  Results for each ensemble ----
# {0:         Accuracy  Precision  Sensitivity  Specificity  F1_score  Balanced Accuracy
#  Green  0.8259    0.9599     0.7908       0.9156       0.8672    0.8532
#  Yellow 0.9117    0.4593     0.8587       0.9161       0.5985    0.8874
#  Amber  0.8869    0.6250     0.7115       0.9199       0.6654    0.8157
#  Red    0.9515    0.4889     0.8884       0.9546       0.6307    0.9215
#  Macro  0.8940    0.6333     0.8123       0.9265       0.6905    0.8694            ,
#  1:         Accuracy  Precision  Sensitivity  Specificity  F1_score  Balanced Accuracy
#  Green  0.8242    0.9647     0.7841       0.9267       0.8651    0.8554
#  Yellow 0.8988    0.4218     0.8641       0.9017       0.5668    0.8829
#  Amber  0.8861    0.6250     0.6983       0.9213       0.6596    0.8098
#  Red    0.9565    0.5190     0.9152       0.9585       0.6624    0.9368
#  Macro  0.8914    0.6326     0.8154       0.9271       0.6885    0.8712            ,
#  2:         Accuracy  Precision  Sensitivity  Specificity  F1_score  Balanced Accuracy
#  Green  0.8157    0.9652     0.7713       0.9289       0.8574    0.8501
#  Yellow 0.9079    0.4470     0.8478       0.9129       0.5854    0.8804
#  Amber  0.8734    0.5865     0.6746       0.9107       0.6275    0.7926
#  Red    0.9415    0.4397     0.9286       0.9421       0.5968    0.9353
#  Macro  0.8846    0.6096     0.8056       0.9237       0.6668    0.8646            ,
#  3:         Accuracy  Precision  Sensitivity  Specificity  F1_score  Balanced Accuracy
#  Green  0.8282    0.9639     0.7904       0.9245       0.8686    0.8575
#  Yellow 0.9109    0.4556     0.8370       0.9170       0.5900    0.8770
#  Amber  0.8754    0.5899     0.6957       0.9092       0.6385    0.8024
#  Red    0.9523    0.4938     0.8839       0.9556       0.6336    0.9198
#  Macro  0.8917    0.6258     0.8017       0.9266       0.6827    0.8642            ,
#  4:         Accuracy  Precision  Sensitivity  Specificity  F1_score  Balanced Accuracy
#  Green  0.8203    0.9695     0.7745       0.9377       0.8611    0.8561
#  Yellow 0.9068    0.4420     0.8311       0.9131       0.5771    0.8721
#  Amber  0.8724    0.5788     0.7071       0.9035       0.6366    0.8053
#  Red    0.9489    0.4742     0.9058       0.9510       0.6225    0.9284
#  Macro  0.8871    0.6161     0.8046       0.9263       0.6743    0.8655            }
